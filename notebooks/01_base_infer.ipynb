# %% [markdown]
# # 01 Base Inference
#
# Load `Qwen/Qwen2.5-0.5B-Instruct` locally and run a few Chinese prompts. This notebook does not train anything.

# %%
import os

os.environ["HF_HOME"] = r"D:\hf_cache"
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

print("HF_HOME =", os.environ["HF_HOME"])

# %% [markdown]
# ## Smoke Test Prompt

# %%
# !python ../scripts/infer.py --prompt '请用三点解释什么是LoRA微调。' --max_new_tokens 256

# %% [markdown]
# ## SFT Understanding Prompt

# %%
# !python ../scripts/infer.py --prompt '请解释SFT和DPO的区别，并说明它们在大模型训练链路中的位置。' --max_new_tokens 384

# %% [markdown]
# ## Local Files Only Check
#
# Run this after the first successful model download. It verifies that the model can be loaded from the local Hugging Face cache.

# %%
# !python ../scripts/infer.py --prompt '请简要说明为什么先用0.5B模型学习LoRA是合理的。' --max_new_tokens 256 --local_files_only
