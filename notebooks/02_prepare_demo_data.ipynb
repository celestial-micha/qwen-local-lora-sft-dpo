# %% [markdown]
# # 02 Prepare Demo Data
#
# Create a tiny built-in SFT dataset for smoke testing. This is not the final training dataset.

# %%
# !python ../scripts/prepare_data.py --demo --train_file ../data/processed/sft_train.jsonl --eval_file ../data/processed/sft_eval.jsonl
